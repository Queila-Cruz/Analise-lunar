# %% [markdown]
# <a href="https://colab.research.google.com/github/Queila-Cruz/Analise-lunar/blob/analise-tipos/Tipos_Missao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AnotherS3/analise-missoes-lunares.git
# Out:
# Cloning into 'analise-missoes-lunares'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 10.23 KiB | 10.23 MiB/s, done.

# %%
# !pip install numpy matplotlib keras

# %%
import pandas as pd

# %%
df_lua = pd.read_csv("/content/analise-missoes-lunares/Moonlanding.csv")

frequencia_missao = (df_lua["Mission Type"].value_counts())
display(frequencia_missao)


minima_missao = frequencia_missao.min()
print(f"Esta foi quantidade minima registrada nas missoes: {minima_missao}")
# Out:
# Mission Type
# Orbiter                                 59
# Lander                                  40
# Flyby                                   31
# Impactor                                15
# Rover                                    6
# Lander,Sample Return                     2
# Orbiter,Lander,Rover                     2
# Flybys                                   2
# Crewed orbiter                           1
# Flyby / Impactor (post mission)          1
# Relay Satellite                          1
# Launch Vehicle                           1
# Sample Return                            1
# Lander                                   1
# Hopper                                   1
# Rovers                                   1
# Deployable camera (semi hard lander)     1
# Name: count, dtype: int64
# Esta foi quantidade minima registrada nas missoes: 1
